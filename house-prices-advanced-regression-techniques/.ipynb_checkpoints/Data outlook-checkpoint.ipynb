# %%
##Friday is the due date for this project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
plt.figure(figsize = (8, 8))
plt.hist(df['SalePrice'], bins = 50, edgecolor = 'black')
plt.title("Sale Price distribution")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.hist(df['SalePrice']/100000, bins = 50, edgecolor = 'black')
plt.title("Sale Price distribution")
plt.show()

# %%
###Using log transform to accurately predict the sale price in the dense part, not the tails
plt.figure(figsize = (8, 8))
plt.hist(np.log(df['SalePrice']), bins = 50, edgecolor = 'black')
plt.title("Log Sale Price distribution")
plt.show()

# %%
df.columns.tolist()
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
##Looking at classification features
##Some of the features do not contain all the classes
##Create a new row to do label encoding with the features

# %%
df1 = df.copy()

# %% [markdown]
# ### MSSubClass

# %%
df1.MSSubClass.value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
np.sort(df1.MSSubClass.unique())
# Out:
# array([ 20,  30,  40,  45,  50,  60,  70,  75,  80,  85,  90, 120, 160,
#        180, 190], dtype=int64)

# %% [markdown]
# ### MSZoning

# %%
df1.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %% [markdown]
# ### LotFrontage

# %%
##lotfrontage is null, can't use it
df1.loc[df1.LotFrontage.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1429  1430          20       RL          NaN    12546   Pave   NaN      IR1
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
#
# ...

# %% [markdown]
# ### Lot Area

# %%
df1.loc[df1.LotArea.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %% [markdown]
# ### Street

# %%
##Not an important feature
df1.Street.value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
df1.loc[df1['Street'] == 'Grvl'].SalePrice
# Out:
# 52      110000
# 335     228950
# 582     118500
# 812      55993
# 1061     81000
# 1184    186700
# Name: SalePrice, dtype: int64

# %% [markdown]
# ### Alley

# %%
df1.Alley.value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
np.sort(df1.loc[(df1['Alley'] == 'Grvl') | (df1['Alley'] == 'Pave')].SalePrice.values)
# Out:
# array([ 40000,  52500,  58500,  64500,  67000,  73000,  87000,  89500,
#         90000,  93000,  96500,  98000, 100000, 102776, 103000, 105000,
#        106250, 106500, 107000, 110000, 110000, 110000, 114504, 115000,
#        115000, 116000, 117000, 119000, 120000, 122000, 124000, 124500,
#        125000, 127000, 128000, 129500, 131500, 132000, 135000, 135000,
#        135900, 136000, 137000, 139400, 140000, 140000, 144152, 145000,
#        146000, 147400, 151000, 151000, 152000, 153500, 153900, 155000,
#        157500, 159434, 159500, 160000, 161000, 163000, 163500, 164500,
#        164700, 168000, 170000, 171900, 172500, 172500, 173733, 174000,
#        176000, 176000, 178000, 179400, 180500, 184000, 185000, 185000,
#        187750, 196000, 197000, 199900, 200000, 207000, 208900, 214500,
#        239000, 256000, 265979], dtype=int64)

# %%
plt.figure(figsize = (8, 8))
plt.hist(np.sort(df1.loc[(df1['Alley'] == 'Grvl') | (df1['Alley'] == 'Pave')].SalePrice.values), bins = 20, edgecolor = 'black')
plt.title("Alley Gravel/Pave Sale Price distribution")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.hist(np.sort(df1.loc[~((df1['Alley'] == 'Grvl') | (df1['Alley'] == 'Pave'))].SalePrice.values), bins = 20, edgecolor = 'black')
plt.title("Alley NA Sale Price distribution")
plt.show()

# %%
df1.Alley.isnull().value_counts()
# Out:
# True     1369
# False      91
# Name: Alley, dtype: int64

# %% [markdown]
# ### LotShape

# %%
df1['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %% [markdown]
# ### LandContour

# %%
df1.LandContour.value_counts()
# Out:
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64

# %% [markdown]
# ### Utilities

# %%
#unnecessary 
df1['Utilities'].value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %% [markdown]
# ### LotConfig

# %%
df1['LotConfig'].value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
df1.loc[df1['LotConfig'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %% [markdown]
# ### LandSlope

# %%
df1['LandSlope'].value_counts()
# Out:
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64

# %% [markdown]
# ### Neighborhood

# %%
neighborhood_trainlist = df1.Neighborhood.unique()

# %%
df1['Neighborhood'].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %% [markdown]
# ### Condition1

# %%
np.sort(df1['Condition1'].unique())
# Out:
# array(['Artery', 'Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn', 'RRNe',
#        'RRNn'], dtype=object)

# %%
df1['Condition1'].value_counts().sum()
# Out:
# 1460

# %% [markdown]
# ### Condition2

# %%
np.sort(df1['Condition2'].unique())
# Out:
# array(['Artery', 'Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn', 'RRNn'],
#       dtype=object)

# %%
df1['Condition2'].value_counts().sum()
# Out:
# 1460

# %%
df1['Condition2'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Type of dwelling

# %%
df1['BldgType'].value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %% [markdown]
# ### HouseStyle

# %%
df1['HouseStyle'].value_counts()
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %% [markdown]
# ### Overall Quality

# %%
df1['OverallQual'].value_counts().sum()
# Out:
# 1460

# %%
plt.figure(figsize = (8, 8))
plt.hist(df1['OverallQual'], bins = 10, edgecolor = 'black')
plt.title("Overall Quality distribution")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['OverallQual'], df1['SalePrice'])
z = np.polyfit(df1['OverallQual'], df1['SalePrice'], 1)
p = np.poly1d(z)
plt.plot(df1['OverallQual'], p(df1['OverallQual']), "r")
plt.title("Overall Quality vs. SalePrice")
plt.show()

# %% [markdown]
# ### OverallCond

# %%
df1['OverallCond'].value_counts()
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64

# %%
df1['OverallCond'].value_counts().sum()
# Out:
# 1460

# %%
plt.figure(figsize = (8, 8))
plt.hist(df1['OverallCond'], bins = 9, edgecolor = 'black')
plt.title("Overall Condition distribution")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['OverallCond'], df1['SalePrice'])
z = np.polyfit(df1['OverallCond'], df1['SalePrice'], 1)
p = np.poly1d(z)
plt.plot(df1['OverallCond'], p(df1['OverallCond']), "r")
plt.title("Overall Condition vs. SalePrice")
plt.show()

# %% [markdown]
# ### YearBuilt

# %%
plt.figure(figsize = (8, 8))
plt.hist(df1['YearBuilt'], bins = 30, edgecolor = 'black')
plt.title("Year Built distribution")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['YearBuilt'], df1['SalePrice'])
z = np.polyfit(df1['YearBuilt'], df1['SalePrice'], 1)
p = np.poly1d(z)
plt.plot(df1['YearBuilt'], p(df1['YearBuilt']), "r")
plt.xlabel('Year')
plt.ylabel('Price')
plt.title("Sale Price vs. YearBuilt")
plt.show()

# %% [markdown]
# ### YearRemoAdd

# %%
plt.figure(figsize = (8, 8))
plt.hist(df1['YearRemodAdd'], bins = 30, edgecolor = 'black')
plt.title("Remodel date distribution")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['YearRemodAdd'], df1['SalePrice'])
z = np.polyfit(df1['YearRemodAdd'], df1['SalePrice'], 1)
p = np.poly1d(z)
plt.plot(df1['YearRemodAdd'], p(df1['YearRemodAdd']), "r")
plt.xlabel('Year')
plt.ylabel('Price')
plt.title("Sale Price vs. Year Remodel")
plt.show()

# %%
df1['YearRemodAdd'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### RoofStyle

# %%
df1['RoofStyle'].value_counts()
# Out:
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64

# %% [markdown]
# ### RoofMatl

# %%
df1['RoofMatl'].value_counts()
# Out:
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Metal         1
# Membran       1
# Roll          1
# ClyTile       1
# Name: RoofMatl, dtype: int64

# %% [markdown]
# ### Exterior1st

# %%
df1['Exterior1st'].value_counts()
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# AsphShn      1
# ImStucc      1
# CBlock       1
# Name: Exterior1st, dtype: int64

# %%
np.sort(df1['Exterior1st'].unique())
# Out:
# array(['AsbShng', 'AsphShn', 'BrkComm', 'BrkFace', 'CBlock', 'CemntBd',
#        'HdBoard', 'ImStucc', 'MetalSd', 'Plywood', 'Stone', 'Stucco',
#        'VinylSd', 'Wd Sdng', 'WdShing'], dtype=object)

# %% [markdown]
# ### Exterior2nd

# %%
df1['Exterior2nd'].value_counts().sum()
# Out:
# 1460

# %%
np.sort(df1['Exterior2nd'].unique())
# Out:
# array(['AsbShng', 'AsphShn', 'Brk Cmn', 'BrkFace', 'CBlock', 'CmentBd',
#        'HdBoard', 'ImStucc', 'MetalSd', 'Other', 'Plywood', 'Stone',
#        'Stucco', 'VinylSd', 'Wd Sdng', 'Wd Shng'], dtype=object)

# %% [markdown]
# ### MasVnrType

# %%
df1['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %% [markdown]
# ### ExterQual

# %%
df1['ExterQual'].value_counts()
# Out:
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: ExterQual, dtype: int64

# %% [markdown]
# ### ExterCond

# %%
df1['ExterCond'].value_counts()
# Out:
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64

# %% [markdown]
# ### Foundation

# %%
df1['Foundation'].value_counts()
# Out:
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64

# %% [markdown]
# ### BsmtQual

# %%
df1['BsmtQual'].value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
df1.loc[df1['BsmtQual'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 39      40          90       RL         65.0     6040   Pave   NaN      Reg
# 90      91          20       RL         60.0     7200   Pave   NaN      Reg
# 102    103          90       RL         64.0     7018   Pave   NaN      Reg
# 156    157          20       RL         60.0     7200   Pave   NaN      Reg
# 182    183          20       RL         60.0     9060   Pave   NaN      Reg
# 259    260          20       RM         70.0    12702   Pave   NaN      Reg
# 342    343          90       RL          NaN     8544   Pave   NaN      Reg
# 362    363          85       RL         64.0     7301   Pave   NaN      Reg
# 371    372          50       RL         80.0    17120   Pave   NaN      Reg
# 392    393          20       RL          NaN     8339   Pave   NaN      IR1
# ...

# %% [markdown]
# ### BsmtCond

# %%
df1['BsmtCond'].value_counts()
# Out:
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64

# %%
df1.loc[df1['BsmtCond'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 39      40          90       RL         65.0     6040   Pave   NaN      Reg
# 90      91          20       RL         60.0     7200   Pave   NaN      Reg
# 102    103          90       RL         64.0     7018   Pave   NaN      Reg
# 156    157          20       RL         60.0     7200   Pave   NaN      Reg
# 182    183          20       RL         60.0     9060   Pave   NaN      Reg
# 259    260          20       RM         70.0    12702   Pave   NaN      Reg
# 342    343          90       RL          NaN     8544   Pave   NaN      Reg
# 362    363          85       RL         64.0     7301   Pave   NaN      Reg
# 371    372          50       RL         80.0    17120   Pave   NaN      Reg
# 392    393          20       RL          NaN     8339   Pave   NaN      IR1
# ...

# %% [markdown]
# ### BsmtExposure

# %%
df1['BsmtExposure'].value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
df1.loc[df1['BsmtExposure'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 39      40          90       RL         65.0     6040   Pave   NaN      Reg
# 90      91          20       RL         60.0     7200   Pave   NaN      Reg
# 102    103          90       RL         64.0     7018   Pave   NaN      Reg
# 156    157          20       RL         60.0     7200   Pave   NaN      Reg
# 182    183          20       RL         60.0     9060   Pave   NaN      Reg
# 259    260          20       RM         70.0    12702   Pave   NaN      Reg
# 342    343          90       RL          NaN     8544   Pave   NaN      Reg
# 362    363          85       RL         64.0     7301   Pave   NaN      Reg
# 371    372          50       RL         80.0    17120   Pave   NaN      Reg
# 392    393          20       RL          NaN     8339   Pave   NaN      IR1
# ...

# %% [markdown]
# ### BsmtFinType1

# %%
df1['BsmtFinType1'].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %% [markdown]
# ### BsmtFinSF1

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['BsmtFinSF1'], df1['SalePrice'])
z = np.polyfit(df1['BsmtFinSF1'], df1['SalePrice'], 1)
p = np.poly1d(z)
plt.plot(df1['BsmtFinSF1'], p(df1['BsmtFinSF1']), "r")
plt.title("Basement Type 1 square feet vs. SalePrice")
plt.show()

# %% [markdown]
# ### BsmtFinType2

# %%
df1['BsmtFinType2'].value_counts()
# Out:
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %% [markdown]
# ### BsmtFinSF2

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['BsmtFinSF2'], df1['SalePrice'])
plt.title("Basement Type 2 square feet vs. SalePrice")
plt.show()

# %% [markdown]
# ### BsmtUnfSF

# %%
df1['BsmtUnfSF'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['BsmtUnfSF'], df1['SalePrice'])
plt.title("Basement Unfinished square feet vs. SalePrice")
plt.show()

# %% [markdown]
# ### TotalBsmtSF

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['TotalBsmtSF'], df1['SalePrice'])
plt.title("Total Basement square feet vs. SalePrice")
plt.show()

# %% [markdown]
# ### Heating

# %%
df1['Heating'].value_counts()
# Out:
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %% [markdown]
# ### HeatingQC

# %%
df1['HeatingQC'].value_counts()
# Out:
# Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64

# %% [markdown]
# ### Central Air

# %%
df1['CentralAir'].value_counts().sum()
# Out:
# 1460

# %% [markdown]
# ### Electrical

# %%
df1['Electrical'].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %% [markdown]
# ### 1stFlrSF

# %%
df1['1stFlrSF'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['1stFlrSF'], df1['SalePrice'])

plt.title("First floor square feet vs. SalePrice")
plt.show()

# %% [markdown]
# ### 2ndFlrSF

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['2ndFlrSF'], df1['SalePrice'])
plt.title("Second floor square feet vs. SalePrice")
plt.show()

# %% [markdown]
# ### LowQualFinSF

# %%
df1['LowQualFinSF'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['LowQualFinSF'], df1['SalePrice'])
plt.title("All floor square feet vs. SalePrice")
plt.show()

# %% [markdown]
# ### GrLivArea

# %%
df1['GrLivArea'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['GrLivArea'], df1['SalePrice'])
plt.title("Above ground living area square feet vs. SalePrice")
plt.show()

# %% [markdown]
# ### BsmtFullBath

# %%
df1['BsmtFullBath'].isnull().sum()
# Out:
# 0

# %%
##Number of full bathrooms
plt.figure(figsize = (8, 8))
plt.hist(df1['BsmtFullBath'], bins = 3, edgecolor = 'black')
plt.title("Basement full bath distribution")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['BsmtFullBath'], df1['SalePrice'])
plt.title("Basement full bath vs. SalePrice")
plt.show()

# %% [markdown]
# ### BsmtHalfBath

# %%
df1['BsmtHalfBath'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['BsmtHalfBath'], df1['SalePrice'])
plt.title("Basement Half bath vs. SalePrice")
plt.show()

# %% [markdown]
# ### FullBath

# %%
df1['FullBath'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['FullBath'], df1['SalePrice'])
plt.title("Fullbath vs. SalePrice")
plt.show()

# %% [markdown]
# ### HalfBath

# %%
df1['HalfBath'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['FullBath'], df1['SalePrice'])
plt.title("Halfbath vs. SalePrice")
plt.show()

# %% [markdown]
# ### Bedroom

# %%
df1['BedroomAbvGr'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['BedroomAbvGr'], df1['SalePrice'])
plt.title("BedroomAbvGr vs. SalePrice")
plt.show()

# %% [markdown]
# ### Kitchen

# %%
df1['KitchenAbvGr'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['KitchenAbvGr'], df1['SalePrice'])
plt.title("KitchenAbvGr vs. SalePrice")
plt.show()

# %% [markdown]
# ### KitchenQual

# %%
df1['KitchenQual'].isnull().sum()
# Out:
# 0

# %%
df1['KitchenQual'].value_counts()
# Out:
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: KitchenQual, dtype: int64

# %% [markdown]
# ### TotRmsAbvGrd

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['TotRmsAbvGrd'], df1['SalePrice'])
plt.title("TotRmsAbvGr vs. SalePrice")
plt.show()

# %% [markdown]
# ### Functional

# %%
df1['Functional'].value_counts()
# Out:
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64

# %% [markdown]
# ### Fireplaces

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['Fireplaces'], df1['SalePrice'])
plt.title("Number of fireplaces vs. SalePrice")
plt.show()

# %% [markdown]
# ### FireplaceQu

# %%
df1['FireplaceQu'].value_counts().sum()
# Out:
# 770

# %%
df1['FireplaceQu'].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# ### GarageType

# %%
df1['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
df1['GarageType'].value_counts().sum()
# Out:
# 1379

# %% [markdown]
# ### GarageYrBuilt

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['GarageYrBlt'], df1['SalePrice'])
plt.title("Year Garage Built vs. SalePrice")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['GarageYrBlt'], df1['YearBuilt'])
plt.xlabel("Garage Year")
plt.ylabel("House Year")
plt.title("Year Garage Built vs. Year the house is built")
plt.show()

# %% [markdown]
# ### GarageFinish

# %%
df1['GarageFinish'].value_counts().sum()
# Out:
# 1379

# %%
df1['GarageFinish'].value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %% [markdown]
# ### GarageCars

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['GarageCars'], df1['SalePrice'])
plt.xlabel("Garage Cars")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Garage Cars")
plt.show()

# %% [markdown]
# ### GarageArea

# %%
df['GarageArea'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['GarageArea'], df1['SalePrice'])
plt.xlabel("Garage Area")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Garage Area")
plt.show()

# %% [markdown]
# ### GarageQual

# %%
df1['GarageQual'].value_counts().sum()
# Out:
# 1379

# %%
df1['GarageQual'].value_counts()
# Out:
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64

# %% [markdown]
# ### GarageCond

# %%
df1['GarageCond'].value_counts().sum()
# Out:
# 1379

# %%
df1['GarageCond'].value_counts()
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %% [markdown]
# ### PavedDrive

# %%
df1['PavedDrive'].value_counts().sum()
# Out:
# 1460

# %%
df1['PavedDrive'].value_counts()
# Out:
# Y    1340
# N      90
# P      30
# Name: PavedDrive, dtype: int64

# %% [markdown]
# ### WoodDeckSF

# %%
df1['WoodDeckSF'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['WoodDeckSF'], df1['SalePrice'])
plt.xlabel("Wood Deck Area")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Wood Deck Area")
plt.show()

# %% [markdown]
# ### OpenPorchSF

# %%
df1['OpenPorchSF'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['OpenPorchSF'], df1['SalePrice'])
plt.xlabel("Open Porch Area")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Open Porch Area")
plt.show()

# %% [markdown]
# ### EnclosedPorch

# %%
df1['EnclosedPorch'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['EnclosedPorch'], df1['SalePrice'])
plt.xlabel("Enclosed Porch Area")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Enclosed Porch Area")
plt.show()

# %% [markdown]
# ### 3SsnPorch

# %%
df1['3SsnPorch'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['3SsnPorch'], df1['SalePrice'])
plt.xlabel("3Ssn Porch Area")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Three season porch Area")
plt.show()

# %% [markdown]
# ### ScreenPorch

# %%
df1['ScreenPorch'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['ScreenPorch'], df1['SalePrice'])
plt.xlabel("Screen Porch Area")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Screen Porch Area")
plt.show()

# %% [markdown]
# ### PoolArea

# %%
df1['PoolArea'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['PoolArea'], df1['SalePrice'])
plt.xlabel("Pool Area")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Pool Area")
plt.show()

# %% [markdown]
# ### PoolQC

# %%
df1['PoolQC'].value_counts()
# Out:
# Gd    3
# Ex    2
# Fa    2
# Name: PoolQC, dtype: int64

# %% [markdown]
# ### Fence

# %%
df1['Fence'].value_counts()
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %% [markdown]
# ### MiscFeature

# %%
df1['MiscFeature'].value_counts()
# Out:
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %% [markdown]
# ### MiscVal

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['MiscVal'], df1['SalePrice'])
plt.xlabel("Miscelaneous feature value")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. MiscVal")
plt.show()

# %% [markdown]
# ### MoSold

# %%
df1['MoSold'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['MoSold'], df1['SalePrice'])
plt.xlabel("Month Sold")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Month Sold")
plt.show()

# %% [markdown]
# ### YrSold

# %%
df1['YrSold'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df1['YrSold'], df1['SalePrice'])
plt.xlabel("Year Sold")
plt.ylabel("Sale Price")
plt.title("Sale Price vs. Year Sold")
plt.show()

# %% [markdown]
# ### SaleType

# %%
df1['SaleType'].isnull().sum()
# Out:
# 0

# %%
df1['SaleType'].value_counts()
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64

# %% [markdown]
# ### Sale Condition

# %%
df1['SaleCondition'].value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %% [markdown]
# # Test set

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df_test['MSZoning'].value_counts().sum()
# Out:
# 1455

# %%
df_test.loc[df_test['MSZoning'].isnull()][['Neighborhood', 'MSZoning']]
# Out:
#      Neighborhood MSZoning
# 455        IDOTRR      NaN
# 756        IDOTRR      NaN
# 790        IDOTRR      NaN
# 1444      Mitchel      NaN

# %%
df_test.loc[df_test['Neighborhood'] == 'IDOTRR'][['Neighborhood', 'MSZoning']]
# Out:
#      Neighborhood MSZoning
# 140        IDOTRR       RM
# 141        IDOTRR       RM
# 142        IDOTRR  C (all)
# 362        IDOTRR  C (all)
# 372        IDOTRR       RM
# 375        IDOTRR       RM
# 376        IDOTRR       RM
# 377        IDOTRR       RM
# 452        IDOTRR       RM
# 453        IDOTRR  C (all)
# 455        IDOTRR      NaN
# 668        IDOTRR       RM
# 669        IDOTRR       RM
# 670        IDOTRR       RM
# 671        IDOTRR       RM
# 672        IDOTRR       RM
# 673        IDOTRR       RM
# 674        IDOTRR       RM
# 675        IDOTRR       RM
# 750        IDOTRR       RM
# 751        IDOTRR       RM
# 752        IDOTRR       RM
# 753        IDOTRR       RM
# 754        IDOTRR       RM
# 755        IDOTRR       RM
# 756        IDOTRR      NaN
# 757        IDOTRR  C (all)
# 758        IDOTRR  C (all)
# 759        IDOTRR  C (all)
# 790        IDOTRR      NaN
# 1009       IDOTRR       RM
# 1010       IDOTRR       RM
# 1011       IDOTRR       RM
# ...

# %%
df_test.loc[df_test.LotFrontage.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 6     1467          20       RL          NaN     7980   Pave   NaN      IR1
# 40    1501         160       FV          NaN     2980   Pave   NaN      Reg
# 41    1502         160       FV          NaN     2403   Pave   NaN      IR1
# 45    1506          20       RL          NaN    10456   Pave   NaN      IR1
# 47    1508          50       RL          NaN    18837   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1387  2848          20       RL          NaN    11088   Pave   NaN      Reg
# 1390  2851          60       RL          NaN    21533   Pave   NaN      IR2
# 1440  2901          20       RL          NaN    50102   Pave   NaN      IR1
# 1441  2902          20       RL          NaN     8098   Pave   NaN      IR1
# 1448  2909          90       RL          NaN    11836   Pave   NaN      IR1
#
# ...

# %%
df_test.loc[df_test.LotArea.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []
#
# [0 rows x 80 columns]

# %%
np.sort(df_test.MSSubClass.unique())
# Out:
# array([ 20,  30,  40,  45,  50,  60,  70,  75,  80,  85,  90, 120, 150,
#        160, 180, 190], dtype=int64)

# %%
neighborhood_testlist = df_test.Neighborhood.unique()
np.sort(neighborhood_testlist)
# Out:
# array(['Blmngtn', 'Blueste', 'BrDale', 'BrkSide', 'ClearCr', 'CollgCr',
#        'Crawfor', 'Edwards', 'Gilbert', 'IDOTRR', 'MeadowV', 'Mitchel',
#        'NAmes', 'NPkVill', 'NWAmes', 'NoRidge', 'NridgHt', 'OldTown',
#        'SWISU', 'Sawyer', 'SawyerW', 'Somerst', 'StoneBr', 'Timber',
#        'Veenker'], dtype=object)

# %%
np.sort(neighborhood_trainlist)
# Out:
# array(['Blmngtn', 'Blueste', 'BrDale', 'BrkSide', 'ClearCr', 'CollgCr',
#        'Crawfor', 'Edwards', 'Gilbert', 'IDOTRR', 'MeadowV', 'Mitchel',
#        'NAmes', 'NPkVill', 'NWAmes', 'NoRidge', 'NridgHt', 'OldTown',
#        'SWISU', 'Sawyer', 'SawyerW', 'Somerst', 'StoneBr', 'Timber',
#        'Veenker'], dtype=object)

# %%
np.sort(df1['Condition1'].unique())
# Out:
# array(['Artery', 'Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn', 'RRNe',
#        'RRNn'], dtype=object)

# %%
np.sort(df1['Condition2'].unique())
# Out:
# array(['Artery', 'Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn', 'RRNn'],
#       dtype=object)

# %%
np.sort(df_test['Condition1'].unique())
# Out:
# array(['Artery', 'Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn', 'RRNe',
#        'RRNn'], dtype=object)

# %%
np.sort(df_test['Condition2'].unique())
# Out:
# array(['Artery', 'Feedr', 'Norm', 'PosA', 'PosN'], dtype=object)

# %%
df_test['BldgType'].value_counts()
# Out:
# 1Fam      1205
# TwnhsE     113
# Duplex      57
# Twnhs       53
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
df_test['HouseStyle'].value_counts()
# Out:
# 1Story    745
# 2Story    427
# 1.5Fin    160
# SLvl       63
# SFoyer     46
# 2.5Unf     13
# 1.5Unf      5
# Name: HouseStyle, dtype: int64

# %%
df_test['OverallQual'].value_counts()
# Out:
# 5     428
# 6     357
# 7     281
# 8     174
# 4     110
# 9      64
# 3      20
# 10     13
# 2      10
# 1       2
# Name: OverallQual, dtype: int64

# %%
df_test['OverallCond'].value_counts()
# Out:
# 5    824
# 6    279
# 7    185
# 8     72
# 4     44
# 3     25
# 9     19
# 1      6
# 2      5
# Name: OverallCond, dtype: int64

# %%
df_test['RoofStyle'].value_counts()
# Out:
# Gable      1169
# Hip         265
# Gambrel      11
# Flat          7
# Mansard       4
# Shed          3
# Name: RoofStyle, dtype: int64

# %%
df_test['RoofMatl'].value_counts()
# Out:
# CompShg    1442
# Tar&Grv      12
# WdShake       4
# WdShngl       1
# Name: RoofMatl, dtype: int64

# %%
np.sort(df1['Exterior1st'].unique())
# Out:
# array(['AsbShng', 'AsphShn', 'BrkComm', 'BrkFace', 'CBlock', 'CemntBd',
#        'HdBoard', 'ImStucc', 'MetalSd', 'Plywood', 'Stone', 'Stucco',
#        'VinylSd', 'Wd Sdng', 'WdShing'], dtype=object)

# %%
x = df_test['Exterior1st'].unique()
x[12] = 'A'
np.sort(x)
# Out:
# array(['A', 'AsbShng', 'AsphShn', 'BrkComm', 'BrkFace', 'CBlock',
#        'CemntBd', 'HdBoard', 'MetalSd', 'Plywood', 'Stucco', 'VinylSd',
#        'Wd Sdng', 'WdShing'], dtype=object)

# %%
np.sort(df1['Exterior2nd'].unique())
# Out:
# array(['AsbShng', 'AsphShn', 'Brk Cmn', 'BrkFace', 'CBlock', 'CmentBd',
#        'HdBoard', 'ImStucc', 'MetalSd', 'Other', 'Plywood', 'Stone',
#        'Stucco', 'VinylSd', 'Wd Sdng', 'Wd Shng'], dtype=object)

# %%
x2 = df_test['Exterior2nd'].unique()
x2[14] = 'A'
np.sort(x2)
# Out:
# array(['A', 'AsbShng', 'AsphShn', 'Brk Cmn', 'BrkFace', 'CBlock',
#        'CmentBd', 'HdBoard', 'ImStucc', 'MetalSd', 'Plywood', 'Stone',
#        'Stucco', 'VinylSd', 'Wd Sdng', 'Wd Shng'], dtype=object)

# %%
df1['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df_test['MasVnrType'].value_counts()
# Out:
# None       878
# BrkFace    434
# Stone      121
# BrkCmn      10
# Name: MasVnrType, dtype: int64

# %%
df_test['ExterQual'].value_counts()
# Out:
# TA    892
# Gd    491
# Ex     55
# Fa     21
# Name: ExterQual, dtype: int64

# %%
df_test['ExterCond'].value_counts()
# Out:
# TA    1256
# Gd     153
# Fa      39
# Ex       9
# Po       2
# Name: ExterCond, dtype: int64

# %%
df_test['Foundation'].value_counts()
# Out:
# PConc     661
# CBlock    601
# BrkTil    165
# Slab       25
# Stone       5
# Wood        2
# Name: Foundation, dtype: int64

# %%
df_test['BsmtQual'].value_counts()
# Out:
# TA    634
# Gd    591
# Ex    137
# Fa     53
# Name: BsmtQual, dtype: int64

# %%
df_test['BsmtCond'].value_counts()
# Out:
# TA    1295
# Fa      59
# Gd      57
# Po       3
# Name: BsmtCond, dtype: int64

# %%
df_test['BsmtExposure'].value_counts()
# Out:
# No    951
# Av    197
# Gd    142
# Mn    125
# Name: BsmtExposure, dtype: int64

# %%
df_test['BsmtFinType1'].value_counts()
# Out:
# GLQ    431
# Unf    421
# ALQ    209
# Rec    155
# BLQ    121
# LwQ     80
# Name: BsmtFinType1, dtype: int64

# %%
df_test['BsmtFinType2'].value_counts()
# Out:
# Unf    1237
# Rec      51
# LwQ      41
# BLQ      35
# ALQ      33
# GLQ      20
# Name: BsmtFinType2, dtype: int64

# %%
df1['Heating'].value_counts()
# Out:
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %%
df_test['Heating'].value_counts()
# Out:
# GasA    1446
# GasW       9
# Grav       2
# Wall       2
# Name: Heating, dtype: int64

# %%
df_test['HeatingQC'].value_counts()
# Out:
# Ex    752
# TA    429
# Gd    233
# Fa     43
# Po      2
# Name: HeatingQC, dtype: int64

# %%
df_test['CentralAir'].value_counts().sum()
# Out:
# 1459

# %%
df1['Electrical'].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
df_test['Electrical'].value_counts()
# Out:
# SBrkr    1337
# FuseA      94
# FuseF      23
# FuseP       5
# Name: Electrical, dtype: int64

# %%
df_test['1stFlrSF'].isnull().sum()
# Out:
# 0

# %%
df_test['2ndFlrSF'].isnull().sum()
# Out:
# 0

# %%
df_test['LowQualFinSF'].isnull().sum()
# Out:
# 0

# %%
df_test['GrLivArea'].isnull().sum()
# Out:
# 0

# %%
df_test['BsmtFullBath'].isnull().sum() ### Assuming null = 0
# Out:
# 2

# %%
df_test['BsmtHalfBath'].isnull().sum()
# Out:
# 2

# %%
df_test['FullBath'].isnull().sum()
# Out:
# 0

# %%
df_test['HalfBath'].isnull().sum()
# Out:
# 0

# %%
df_test['BedroomAbvGr'].isnull().sum()
# Out:
# 0

# %%
df_test['KitchenAbvGr'].isnull().sum()
# Out:
# 0

# %%
df_test['KitchenQual'].value_counts()
# Out:
# TA    757
# Gd    565
# Ex    105
# Fa     31
# Name: KitchenQual, dtype: int64

# %%
df_test.loc[df_test['KitchenQual'].isnull()]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 95  1556          50       RL         72.0    10632   Pave   NaN      IR1
#
#    LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 95         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition
# 95       0      1    2010       COD         Normal
#
# [1 rows x 80 columns]

# %%
df_test.loc[df_test['TotRmsAbvGrd'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []
#
# [0 rows x 80 columns]

# %%
df_test.loc[df_test['Functional'].isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 756   2217          20      NaN         80.0    14584   Pave   NaN      Reg
# 1013  2474          50       RM         60.0    10320   Pave  Grvl      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 756          Low    AllPub  ...           0        0    NaN   NaN         NaN
# 1013         Lvl    AllPub  ...          84        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition
# 756        0      2    2008        WD        Abnorml
# 1013       0      9    2007       COD        Abnorml
#
# [2 rows x 80 columns]

# %%
df_test['Functional'].value_counts()
# Out:
# Typ     1357
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64

# %%
df_test['FireplaceQu'].value_counts()
# Out:
# Gd    364
# TA    279
# Fa     41
# Po     26
# Ex     19
# Name: FireplaceQu, dtype: int64

# %%
df_test['GarageType'].value_counts()
# Out:
# Attchd     853
# Detchd     392
# BuiltIn     98
# Basment     17
# 2Types      17
# CarPort      6
# Name: GarageType, dtype: int64

# %%
df_test['GarageFinish'].value_counts()
# Out:
# Unf    625
# RFn    389
# Fin    367
# Name: GarageFinish, dtype: int64

# %%
df_test['GarageCars'].value_counts()
# Out:
# 2.0    770
# 1.0    407
# 3.0    193
# 0.0     76
# 4.0     11
# 5.0      1
# Name: GarageCars, dtype: int64

# %%
df_test['GarageQual'].value_counts()
# Out:
# TA    1293
# Fa      76
# Gd      10
# Po       2
# Name: GarageQual, dtype: int64

# %%
df_test['GarageCond'].value_counts()
# Out:
# TA    1328
# Fa      39
# Po       7
# Gd       6
# Ex       1
# Name: GarageCond, dtype: int64

# %%
df_test['WoodDeckSF'].isnull().sum()
# Out:
# 0

# %%
df_test['OpenPorchSF'].isnull().sum()
# Out:
# 0

# %%
df_test['EnclosedPorch'].isnull().sum()
# Out:
# 0

# %%
df_test['3SsnPorch'].isnull().sum()
# Out:
# 0

# %%
df_test['ScreenPorch'].isnull().sum()
# Out:
# 0

# %%
df_test['MoSold'].isnull().sum()
# Out:
# 0

# %%
df_test['PoolArea'].isnull().sum()
# Out:
# 0

# %%
df_test['PoolQC'].value_counts()
# Out:
# Ex    2
# Gd    1
# Name: PoolQC, dtype: int64

# %%
df_test['Fence'].value_counts()
# Out:
# MnPrv    172
# GdPrv     59
# GdWo      58
# MnWw       1
# Name: Fence, dtype: int64

# %%
df_test['MiscFeature'].value_counts()
# Out:
# Shed    46
# Gar2     3
# Othr     2
# Name: MiscFeature, dtype: int64

# %%
df_test['MoSold'].isnull().sum()
# Out:
# 0

# %%
df_test['MoSold'].value_counts()
# Out:
# 6     250
# 7     212
# 5     190
# 4     138
# 3     126
# 8     111
# 9      95
# 10     84
# 2      81
# 1      64
# 11     63
# 12     45
# Name: MoSold, dtype: int64

# %%
df_test['YrSold'].isnull().sum()
# Out:
# 0

# %%
df_test['SaleType'].value_counts()
# Out:
# WD       1258
# New       117
# COD        44
# ConLD      17
# CWD         8
# Oth         4
# ConLI       4
# Con         3
# ConLw       3
# Name: SaleType, dtype: int64

# %%
df_test['SaleCondition'].value_counts()
# Out:
# Normal     1204
# Partial     120
# Abnorml      89
# Family       26
# Alloca       12
# AdjLand       8
# Name: SaleCondition, dtype: int64

# %% [markdown]
# # Creating a pipeline for ML

# %%
##Divide the price by 100000 for better estimation
##List of Important features:
##MSSubClass (Label Encoding) (One more row for the class 150 in train)
##MSZoning (Label Encoding)
##LotArea 
##Alley (Label Encoding)
##LotShape (Label Encoding)
##LandContour (Label Encoding)
##LotConfig (Label Encoding)
##LandSlope (Label Encoding)
##Neighborhood (Label Encoding)
##Condition1 (Label Encoding)
##Condition2 (Label Encoding) (add 3 more rows 'RRAe', 'RRAn', 'RRNn' in test)
##BldgType (Label Encoding)
##HouseStyle (Label Encoding) (add one more row for 2.5Fin in test)
##OverallQual (Label Encoding)
##OverallCond (Label Encoding)
##YearBuilt (Normalize?)
##YearRemodAdd (Normalize?)
##RoofStyle (Label Encoding)
##RoofMatl (Label Encoding) (add 4 rows for ClyTile, Membran, Metal, Roll in test)
##Exterior1st (Label Encoding) (add 2 more rows 'ImStucc', 'Stone' in test)
##Exterior2nd (Label Encoding) (add 1 more row 'Other' in test)
##MasVnrType (Label Encoding)
##ExterQual (Label Encoding)
##ExterCond (Label Encoding)
##Foundation (Label Encoding)
##BsmtQual (Label Encoding)
##BsmtCond (Label Encoding)
##BsmtExposure (Label Encoding)
##BsmtFinType1 (Label Encoding)
##BsmtFinSF1
##BsmtFinType2 (Label Encoding)
##BsmtFinSF2
##BsmtUnfSF
##TotalBsmtSF
##Heating (Label Encoding) (add 2 more rows for OthW, Floor in test)
##HeatingQC (label Encoding)
##CentralAir (Label Encoding)
##Electrical (Label Encoding) (add 1 more row for mix in test)
##1stFlrSF
##2ndFlrSF
##LowQualFinSF
##GrLivArea
##BsmtFullBath (Fill the null values with 0's in test) (Label encoding)
##BsmtHalfBath (Fill the null values with 0's in test) (Label encoding)
##HalfBath (Label encoding)
##FullBath (Label encoding)
##Bedroom (Label encoding)
##Kitchen (Label encoding)
##KitchenQual (1 Null value in a existing row in test set) (Label Encoding)
##TotRmsAbvGrd
##Functional (Label encoding) (2 Nan values in 2 existing rows in test set)
##Fireplaces (Label encoding)
##FireplaceQu (Label encoding) (Some houses have fireplaces, some don't)
##GarageType (Label encoding)
##GarageYrBlt
##GarageFinish (Label encoding) 
##GarageCars (Label Encoding) (Add a 5 in the training set)
##GarageArea
##GarageQual (Label encoding) (Add 1 Ex in test set)
##GarageCond (Label encoding) 
##PavedDrive (Label encoding)
##WoodDeckSF 
##OpenPorchSF
##EnclosedPorch
##3SsnPorch
##ScreenPorch
##PoolArea
##PoolQC (Label encoding) (Add 1 Fa in test set)
##Fence (Label encoding)
##MiscFeature (Label encoding) (Add 1 Tenc in test set)
##MiscVal
##MoSold (Label encoding)
##YrSold
##SaleType (Label encoding)
##SaleCondition (Label encoding)

# %%
##'MSSubClass', 'MSZoning', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood',
##'Condition1', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle', 'Exterior1st', 
##'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 
##'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'BsmtFullBath', 'BsmtHalfBath',
##'HalfBath', 'FullBath', 'Bedroom', 'Kitchen'
##'KitchenQual', 'Functional', 'Fireplaces', FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'GarageQual', 
##'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'
